# %%
                                        #Author:@Sirish Prabakar




import numpy as np
import cv2

from PIL import Image
from io import BytesIO
import base64
import matplotlib.pyplot as plt
from skimage import io

# Convert Image to Base64 
def im_2_b64(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = Image.fromarray(image)
    buff = BytesIO()
    image.save(buff, format="JPEG")
    img_str = base64.b64encode(buff.getvalue())
    return img_str

# Convert Base64 to Image
def b64_2_img(data):
    buff = BytesIO(base64.b64decode(data))
    img=Image.open(buff)
    cv_image = cv2.cvtColor(np.asarray(img), cv2.COLOR_RGB2BGR)
    return cv_image

#trial base 64 inputs: input64 for blue sign and input 65 for black sign, this is for testing only, actualy base 64 values should be directly inserted into this program from the calling function

#blue
#signature_image = '...'
#black
signature_image= 'iVBORw0KGgoAAAANSUhEUgAAA1wAAAJwCAYAAACd/GA9AACAAElEQVR42uzdZZQUV/su/PfbWev8kyDjPe3u3ePKMLg7CR5cQ0gIJ'
background_image = '/9j/4AAQSkZJRgABAQIAHAAcAAD/2wBDAAMCAgMCAgMDAwMEAwMEBQgFBQQEBQoHBwYIDAoMDAsKCwsNDhIQDQ4RDgsLEBYQERMUF'
colour_of_signature='black'

y_coordinate=150

x_coordinate=150

#bg and input64 are inputs to this whole program
#----------------------------------------------------------------------------------
colour=colour_of_signature
y_start=y_coordinate
x_start=x_coordinate
#image = b64_2_img(signature_image)
#bg_img = b64_2_img(background_image)
image = cv2.imread(r"C:\Users\siris\OneDrive\Desktop\udemy\DLCV\MasterOpenCV.tar\images\ex3.png")
#image = cv2.imread(r"C:\Users\siris\OneDrive\Desktop\udemy\DLCV\MasterOpenCV.tar\images\sign10.jpg")
bg_img = cv2.imread(r"C:\Users\siris\OneDrive\Desktop\udemy\DLCV\MasterOpenCV.tar\images\bg.jpg")
#----------------------------------------------------------------------------------
if colour=='blue':


    import numpy as np
    import cv2
    sign=image
    result = image.copy()

    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower = np.array([90, 38, 0])
    upper = np.array([145, 255, 255])
    mask = cv2.inRange(image, lower, upper)
    # create an opposite: a mask that holds the background area
    
    #cv2.imshow("result", mask)
    #cv2.waitKey(0)
    
    # create an image of the signature with background excluded
    sign_masked = cv2.bitwise_and(sign,sign,mask=mask)
    #cv2.imshow("result", sign_masked)
    #cv2.waitKey(0)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    cv2.imshow('kernel', kernel)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\kernel.jpg',kernel)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
    cv2.imshow('opening', opening)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\opening.jpg',opening)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    close = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=2)
    cv2.imshow('close', close)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\close.jpg',close)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    
#-------------------------------------------------------------------------------------------------
    # Find Canny edges
    gray = cv2.cvtColor(sign,cv2.COLOR_BGR2GRAY)
    edged = cv2.Canny(gray, 30, 200)
    cv2.imshow('Canny Edges', edged)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\canny edges.jpg',edged)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # Finding Contours
    # Use a copy of your image e.g. edged.copy(), since findContours alters the image
    contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    cv2.imshow('Canny Edges After Contouring', edged)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Canny Edges After Contouring.jpg',edged)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    print("Number of Contours found = " + str(len(contours)))

    # Draw all contours
    # Use '-1' as the 3rd parameter to draw all
    cv2.drawContours(image, contours, -1, (0,255,0), 3)

    cv2.imshow('Contours', image)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Contours.jpg',image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
#---------------------------------------------------------------------------------------------------
    boxes = []
    im=image.copy()
    for c in cnts:
        (x, y, w, h) = cv2.boundingRect(c)

        boxes.append([x,y, x+w,y+h])

    boxes = np.asarray(boxes)
    left = np.min(boxes[:,0])
    top = np.min(boxes[:,1])
    right = np.max(boxes[:,2])
    bottom = np.max(boxes[:,3])
    
    result[close==0] = (255,255,255)
    ROI = result[top:bottom, left:right].copy()
    cv2.rectangle(result, (left,top), (right,bottom), (36, 255, 12), 2)
    cv2.imshow("result", result)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\rectangle.jpg',result)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.imshow("result", ROI)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\cropped.jpg',ROI)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    hsv = cv2.cvtColor(ROI, cv2.COLOR_BGR2HSV)

    # define range of HSV-color of the signature
    lower = np.array([90, 38, 0])
    upper = np.array([145, 255, 255])


    # Threshold the HSV image to get a mask that holds the signature area
    mask = cv2.inRange(hsv, lower, upper)
    cv2.imshow('mask after cropping', mask)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\mask after cropping.jpg',mask)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    mask_inv= cv2.bitwise_not(mask)
    cv2.imshow('inverse mask after cropping', mask_inv)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\inverse mask after cropping.jpg',mask_inv)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    sign_masked = cv2.bitwise_and(ROI,ROI,mask=mask)
    cv2.imshow('signature masked', sign_masked)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\signature mask.jpg',sign_masked)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


    # get the dimensions of the signature
    height, width = ROI.shape[:2]


    #create a subimage of the area where the signature needs to go
    placeToPutSign = bg_img[y_start:height+ y_start,x_start:width+x_start]
    cv2.imshow('Place To Put Sign', placeToPutSign)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Region to put sign.jpg',placeToPutSign)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # exclude signature area 
    placeToPutSign_masked = cv2.bitwise_and(placeToPutSign, placeToPutSign, mask=mask_inv)
    cv2.imshow('placeToPutSign_masked', placeToPutSign_masked)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Region to put sign masked.jpg',placeToPutSign_masked)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # add signature to subimage
    placeToPutSign_joined = cv2.add(placeToPutSign_masked, sign_masked)
    cv2.imshow('placeToPutSign_joined', placeToPutSign_joined)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\placeToPutSign_joined.jpg', placeToPutSign_joined)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # put subimage over main image
    bg_img[y_start:height+y_start,x_start:width+x_start] = placeToPutSign_joined

    # display image
    cv2.imshow("result", bg_img)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\result.jpg', bg_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    bg_img=cv2.resize(bg_img,None,fx=0.3,fy=0.3)
    cv2.imshow("result", bg_img)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\result after resize.jpg', bg_img)
    #----------------------------------------------------------------------------------
    final_64=im_2_b64(bg_img)
    print(final_64)
    #return final_64
    #----------------------------------------------------------------------------------



    cv2.waitKey(0)
    cv2.destroyAllWindows()

if colour=='black':

    import numpy as np
    import cv2
    sign=image
    result = image.copy()

    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower = np.array([0, 0, 0])
    upper = np.array([255, 255, 245])
    mask = cv2.inRange(image, lower, upper)
    # create an opposite: a mask that holds the background area
    
    #cv2.imshow("result", mask)
    #cv2.waitKey(0)
    
    # create an image of the signature with background excluded
    sign_masked = cv2.bitwise_and(sign,sign,mask=mask)
    #cv2.imshow("result", sign_masked)
    #cv2.waitKey(0)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    cv2.imshow('kernel', kernel)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\kernel.jpg',kernel)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
    cv2.imshow('opening', opening)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\opening.jpg',opening)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    close = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=2)
    cv2.imshow('close', close)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\close.jpg',close)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    
#-------------------------------------------------------------------------------------------------
    # Find Canny edges
    gray = cv2.cvtColor(sign,cv2.COLOR_BGR2GRAY)
    edged = cv2.Canny(gray, 30, 200)
    cv2.imshow('Canny Edges', edged)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\canny edges.jpg',edged)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # Finding Contours
    # Use a copy of your image e.g. edged.copy(), since findContours alters the image
    contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    cv2.imshow('Canny Edges After Contouring', edged)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Canny Edges After Contouring.jpg',edged)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    print("Number of Contours found = " + str(len(contours)))

    # Draw all contours
    # Use '-1' as the 3rd parameter to draw all
    cv2.drawContours(image, contours, -1, (0,255,0), 3)

    cv2.imshow('Contours', image)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Contours.jpg',image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
#---------------------------------------------------------------------------------------------------
    boxes = []
    im=image.copy()
    for c in cnts:
        (x, y, w, h) = cv2.boundingRect(c)

        boxes.append([x,y, x+w,y+h])

    boxes = np.asarray(boxes)
    left = np.min(boxes[:,0])
    top = np.min(boxes[:,1])
    right = np.max(boxes[:,2])
    bottom = np.max(boxes[:,3])
    
    result[close==0] = (255,255,255)
    ROI = result[top:bottom, left:right].copy()
    cv2.rectangle(result, (left,top), (right,bottom), (36, 255, 12), 2)
    cv2.imshow("result", result)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\rectangle.jpg',result)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.imshow("result", ROI)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\cropped.jpg',ROI)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    hsv = cv2.cvtColor(ROI, cv2.COLOR_BGR2HSV)

    # define range of HSV-color of the signature
    lower = np.array([0, 0, 0])
    upper = np.array([255, 255, 245])


    # Threshold the HSV image to get a mask that holds the signature area
    mask = cv2.inRange(hsv, lower, upper)
    cv2.imshow('mask after cropping', mask)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\mask after cropping.jpg',mask)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    mask_inv= cv2.bitwise_not(mask)
    cv2.imshow('inverse mask after cropping', mask_inv)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\inverse mask after cropping.jpg',mask_inv)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    sign_masked = cv2.bitwise_and(ROI,ROI,mask=mask)
    cv2.imshow('signature masked', sign_masked)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\signature mask.jpg',sign_masked)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


    # get the dimensions of the signature
    height, width = ROI.shape[:2]


    #create a subimage of the area where the signature needs to go
    placeToPutSign = bg_img[y_start:height+ y_start,x_start:width+x_start]
    cv2.imshow('Place To Put Sign', placeToPutSign)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Region to put sign.jpg',placeToPutSign)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # exclude signature area 
    placeToPutSign_masked = cv2.bitwise_and(placeToPutSign, placeToPutSign, mask=mask_inv)
    cv2.imshow('placeToPutSign_masked', placeToPutSign_masked)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\Region to put sign masked.jpg',placeToPutSign_masked)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # add signature to subimage
    placeToPutSign_joined = cv2.add(placeToPutSign_masked, sign_masked)
    cv2.imshow('placeToPutSign_joined', placeToPutSign_joined)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\placeToPutSign_joined.jpg', placeToPutSign_joined)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # put subimage over main image
    bg_img[y_start:height+y_start,x_start:width+x_start] = placeToPutSign_joined

    # display image
    cv2.imshow("result", bg_img)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\result.jpg', bg_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    bg_img=cv2.resize(bg_img,None,fx=0.3,fy=0.3)
    cv2.imshow("result", bg_img)
    cv2.imwrite(r'C:\Users\siris\OneDrive\Desktop\230\pics\result after resize.jpg', bg_img)
    #----------------------------------------------------------------------------------
    final_64=im_2_b64(bg_img)
    print(final_64)
    #return final_64
    #----------------------------------------------------------------------------------



    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Number of Contours found = 1
# b'...'
